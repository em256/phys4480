# %% [markdown]
# # Bonus LAB -- Dynamics

# %% [markdown]
# This is a bonus lab -- you do not need to hand this in.

# %%
import Pkg
Pkg.activate(".")
Pkg.add(["Plots","DifferentialEquations","OrdinaryDiffEq","Logging"]) # Caution takes some time to run the first time 
Pkg.instantiate()
# Out:
#   Activating project at `~/Documents/MacbookPro/PHYS 4480-7680 Computational Physics/lectures 2026`
#      Project No packages added to or removed from `~/Documents/MacbookPro/PHYS 4480-7680 Computational Physics/lectures 2026/Project.toml`
#     Manifest No packages added to or removed from `~/Documents/MacbookPro/PHYS 4480-7680 Computational Physics/lectures 2026/Manifest.toml`

# %% [markdown]
# **Please write your name in this box**

# %% [markdown]
# *We encourage you to work together, and seek whatever help you need in completing this lab.  Please list all people who you worked with or received help from*

# %% [markdown]
# *We encourage you to use any online resources that you find useful. Please list any URL's that you consulted*

# %% [markdown]
# *We encourage you to use AI resources if you find them useful.  If you made use of AI, please list the platform and the prompts which you made use of*

# %% [markdown]
# ## Goal

# %% [markdown]
# Use the tools that you have developed to study some interesting phenomenon from physics.  Some examples:
#
# - Celestial Dynamics
#     - Can you model circular and elliptical orbits for motion in a central gravitational potential?
#     - Verify Kepler's laws?
#     - Gravitational Slingshot?
#     - Lagrange points?
#     - 3-body problem
# - Double pendulum
#     - Observe regular and chaotic motion
# - Bouncing Ball
#     - Include finite coefficient of restitution at bounce
# - Lorenz equations
